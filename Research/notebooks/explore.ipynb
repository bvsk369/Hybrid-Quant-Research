# %%
import pandas as pd

# %%
file_path="Research\Data\ICICIBANK_Cleaned_Final.csv"

# %%
file_path = "Research/Data/ICICIBANK_Cleaned_Final.csv"

# %%
df=pd.read_csv(file_path)

# %%
file_path = "Data/ICICIBANK_Cleaned_Final.csv" 
df = pd.read_csv(file_path)

# %%
import os
print(f"I am currently in: {os.getcwd()}")
print(f"Folders I can see here: {os.listdir()}")

# %%
file_path = "../Data/ICICIBANK_Cleaned_Final.csv"

# %%
df=pd.read_csv(file_path)|

# %%
df=pd.read_csv(file_path)

# %%
df

# %%
df = pd.read_csv("../Data/ICICIBANK_Cleaned_Final.csv", index_col=0, parse_dates=True)

print(df.index) # This should now show 'DatetimeIndex'

# %%
df

# %%
df.index.rename_axis('timestamp', inplace=True)

# %%
df.rename_axis('timestamp', axis=0, inplace=True)

# %%
df

# %%
from feature import add_log_returns

# %%
import sys
sys.path.append("../"
from src.feature import add_log_returns

# %%
import sys
sys.path.append("../") # This tells Python: "Look one folder up for modules"

from src.feature import add_log_returns

# %%
df_final = add_log_returns(df_final)

# %%
df_final=df
df_final=add_log_returns(df_final)

# %%
df

# %%
(df['close'] == 0).sum()

# %%
df_final = df.copy()

# %%
price_cols = ['open', 'high', 'low', 'close']

df_final[price_cols] = df_final[price_cols].replace(0, np.nan)

# %%
import numpy as np

# %%
price_cols = ['open', 'high', 'low', 'close']

df_final[price_cols] = df_final[price_cols].replace(0, np.nan)

# %%
df_final[price_cols] = df_final[price_cols].ffill().bfill()

# %%
(df_final[price_cols] <= 0).sum()
df_final[price_cols].isna().sum()

# %%
df_final = add_log_returns(df_final)

# %%
df_final

# %%
df_final = pd.read_csv("../Data/feature1.csv")

# %%
df_final.to_csv("../Data/feature1.csv", index=False)
